# %%
A=10

# %%
print(A)
# Out:
# 10

# %% [markdown]
# # Identifier

# %%
A=10

# %% [markdown]
# # rules for creating identifier

# %% [markdown]
# ## 1. start with alphabet or underscore

# %%
a=10

# %%
A=10

# %%
_a=10

# %%
_A=10

# %%
1a=10
# Out:
#   Cell In[11], line 1
#     1a=10
#     ^
# SyntaxError: invalid decimal literal

# %%
@a=10
# Out:
#   Cell In[12], line 1
#     @a=10
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %% [markdown]
# # 2. followed by zero or more letters/alphabets & digits

# %%
age=25

# %%
age1=10

# %%
_age1=10

# %% [markdown]
# # 3.keyword cannot be identifier

# %%
False=10
# Out:
#   Cell In[18], line 1
#     False=10
#     ^
# SyntaxError: cannot assign to False

# %% [markdown]
# # Python is dynamically typed language

# %%
age=25

# %%
print(age)
# Out:
# 25

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
age="twenty-five"

# %%
print(age)
# Out:
# twenty-five

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age=25+0j

# %%
print(age)
# Out:
# (25+0j)

# %%
print(type(age))
# Out:
# <class 'complex'>
