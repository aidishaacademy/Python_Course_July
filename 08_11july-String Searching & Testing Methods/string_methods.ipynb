# %% [markdown]
# ## String Methods

# %% [markdown]
# ### String content test methods

# %%
str1="jai ganesh"

# %%
print(str1)
# Out:
# jai ganesh

# %%
print(type(str1))
# Out:
# <class 'str'>

# %%
print(id(str1))
# Out:
# 4477970096

# %%
print(str1.upper())
# Out:
# JAI GANESH

# %% [markdown]
# #### 1. isalpha ( )

# %%
str1="Jaiganesh"

# %%
print(str1.isalpha())
# Out:
# True

# %%
str2="jaiganesh1"

# %%
print(str2.isalpha())
# Out:
# False

# %%
str3="jaiganesh@"

# %%
print(str3.isalpha())
# Out:
# False

# %% [markdown]
# ## 2. isdigit ( )

# %%
str4="12345"

# %%
print(str4.isdigit())
# Out:
# True

# %%
str5="hello123"

# %%
print(str5.isdigit())
# Out:
# False

# %% [markdown]
# #### 3. isalnum ( )

# %%
str6="helloworld"
str7="12345"
str8="hello123"

# %%
print(str6.isalnum())
# Out:
# True

# %%
print(str7.isalnum())
# Out:
# True

# %%
print(str8.isalnum())
# Out:
# True

# %%
str9="hello123$"

# %%
print(str9.isalnum())
# Out:
# False

# %% [markdown]
# #### 4. islower ( )

# %%
str10="hello"

# %%
print(str10.islower())
# Out:
# True

# %%
str11="Hello"

# %%
print(str11.islower())
# Out:
# False

# %% [markdown]
# #### 5. isupper ( )

# %%
str12="HELLO"

# %%
print(str12.isupper())
# Out:
# True

# %%
str13="HELLo"

# %%
print(str13.isupper())
# Out:
# False

# %% [markdown]
# #### 6.startswith ( )

# %%
str14="jai ganesh"

# %%
print(str14.startswith("jai"))
# Out:
# True

# %%
print(str14.startswith("shree"))
# Out:
# False

# %% [markdown]
# #### 7. endswith ( )

# %%
str15="jai ganesh"

# %%
print(str15.endswith("ganesh"))
# Out:
# True

# %%
print(str15.endswith("Ganesh"))
# Out:
# False

# %% [markdown]
# ## 2. Searching method

# %% [markdown]
# #### find ( )

# %%
text="Hello, welcome to python programming. python is very easy"

# %%
print(text.find("python"))
# Out:
# 18

# %%
print(text.find("java"))
# Out:
# -1
