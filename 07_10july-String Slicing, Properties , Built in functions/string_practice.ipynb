# %% [markdown]
# ## String slicing

# %%
str1="jai ganesh"

# %%
print(str1[0:3:1])
# Out:
# jai

# %%
print(str1[0:3:1])
# Out:
# jai

# %%
print(str1[4:10:1])
# Out:
# ganesh

# %%
print(str1[6:10:1])
# Out:
# nesh

# %%
print(len(str1))
# Out:
# 10

# %%
print(str1[::])
# Out:
# jai ganesh

# %%
print(str1[0:10:1])
# Out:
# jai ganesh

# %% [markdown]
# #### reverse the string

# %%
print(str1[::-1])
# Out:
# hsenag iaj

# %% [markdown]
# ## String Properties

# %% [markdown]
# #### 1. Immutability

# %%
str1="jai ganesh"

# %%
str1[0]="J"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 str1[0]="J"
#
# TypeError: 'str' object does not support item assignment

# %%
list1=[10,20,30,40,50]

# %%
list1[0]=11

# %%
print(list1)
# Out:
# [11, 20, 30, 40, 50]

# %% [markdown]
# #### 2.concatenation

# %%
str1="jai"

# %%
str2="ganesh"

# %%
str4=" "

# %%
str3=str1+str4+str2

# %%
print(str3)
# Out:
# jai ganesh

# %%
print(type(str3))
# Out:
# <class 'str'>

# %%
str5="hello"+" "+"world"

# %%
print(str5)
# Out:
# hello world

# %% [markdown]
# #### 3. Repetition

# %%
str1="jai ganesh "

# %%
str3=str1*30

# %%
print(str3)
# Out:
# jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh jai ganesh

# %% [markdown]
# #### 4.Indexing.

# %%
str1="jai ganesh"

# %%
print(str1[4])
# Out:
# g

# %% [markdown]
# #### 5.Slicing

# %%
str1="jai ganesh"

# %%
print(str1[0:3:1])
# Out:
# jai

# %% [markdown]
# #### 6. Membership testing

# %%
str1="jai ganesh"

# %%
print("jai" in str1)
# Out:
# True

# %%
print("hello" in str1)
# Out:
# False

# %%
print("ganesh" in str1)
# Out:
# True

# %%
print("Ganesh" in str1)
# Out:
# False

# %%
str1="JaI GanesH"

# %%
print(str1)
# Out:
# JaI GanesH

# %%
str6=""" 
32. Which is better: positive indexing or negative indexing?

Answer:

Both are useful.

* Positive indexing is useful when accessing characters from the beginning.
* Negative indexing is useful when accessing characters from the end.
"""

# %%
print(str6)
# Out:
#
# 32. Which is better: positive indexing or negative indexing?
#
# Answer:
#
# Both are useful.
#
# * Positive indexing is useful when accessing characters from the beginning.
# * Negative indexing is useful when accessing characters from the end.

# %%
print("33" in str6)
# Out:
# False

# %%
str7="JaI GanesH"

# %%
str7="jai ganesh"

# %%
str8=str7.lower()

# %%
print(str8)
# Out:
# jai ganesh

# %%
print("jai" in str8)
# Out:
# True

# %% [markdown]
# ## Built in functions in strings

# %% [markdown]
# #### 1. len()

# %%
str1="jai ganesh"

# %%
print(len(str1))
# Out:
# 10

# %%
str2="jai"

# %%
print(len(str2))
# Out:
# 3

# %%
str3="ganesh"

# %%
print(len(str3))
# Out:
# 6

# %% [markdown]
# #### 2. min()

# %%
str1="ganeshz"
#103,97,110,101,115,104,122

# %%
chr(97)
# Out:
# 'a'

# %%
ord("z")
# Out:
# 122

# %%
print(min(str1))
# Out:
# G

# %% [markdown]
# #### 3. max()

# %%
print(max(str1))
# Out:
# z

# %%
list1=[10,45,67,89,23,56]

# %%
print(min(list1))
# Out:
# 10

# %%
print(max(list1))
# Out:
# 89

# %%
print(len(list1))
# Out:
# 6

# %%
ord("a")
# Out:
# 97
