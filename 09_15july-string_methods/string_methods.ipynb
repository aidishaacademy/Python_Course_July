# %% [markdown]
# ## String methods

# %% [markdown]
# #### replace ( )

# %%
str1="jai ganesh"

# %%
print(str1)
# Out:
# jai ganesh

# %%
new_str=str1.replace("jai","shree")

# %%
print(new_str)
# Out:
# shree ganesh

# %%
print(str1)
# Out:
# jai ganesh

# %% [markdown]
# ## Trim whitespace

# %% [markdown]
# #### 1. lstrip ( )

# %%
str2="    jai ganesh"

# %%
print(str2)
# Out:
#     jai ganesh

# %%
print(str2[0:5])
# Out:
#     j

# %%
new_str1=str2.lstrip()

# %%
print(new_str1)
# Out:
# jai ganesh

# %% [markdown]
# #### rstrip ( )

# %%
str3="jai ganesh    "

# %%
print(str3)
# Out:
# jai ganesh

# %%
new_str2=str3.rstrip()

# %%
print(new_str2)
# Out:
# jai ganesh

# %% [markdown]
# #### strip( )

# %%
str4="    jai ganesh    "

# %%
print(str4)
# Out:
#     jai ganesh

# %%
new_str3=str4.strip()

# %%
print(new_str3)
# Out:
# jai ganesh

# %% [markdown]
# ## Split( ) and partition( )

# %% [markdown]
# #### split( )

# %%
str1="hello welcome to python"

# %%
words=str1.split()

# %%
print(words)
# Out:
# ['hello', 'welcome', 'to', 'python']

# %%
str2="hello welcome to python"

# %%
words1=str1.split(" ")

# %%
print(words1)
# Out:
# ['hello', 'welcome', 'to', 'python']

# %%
str3="python,fastapi,langchain,langgraph"

# %%
print(str3)
# Out:
# python,fastapi,langchain,langgraph

# %%
words2=str3.split(",")

# %%
print(words2)
# Out:
# ['python', 'fastapi', 'langchain', 'langgraph']

# %%
str4="hi , welcome to the, python programming"

# %%
words3=str4.split(",")

# %%
print(words3)
# Out:
# ['hi ', ' welcome to the', ' python programming']

# %% [markdown]
# #### partition( )

# %%
str1="hello welcome to python"

# %%
before,sep,after=str1.partition("to")

# %%
print(before)
# Out:
# hello welcome

# %%
print(sep)
# Out:
# to

# %%
print(after)
# Out:
#  python

# %% [markdown]
# ## String Conversions

# %% [markdown]
# #### lower( )

# %%
str1="JAI GANESH"

# %%
new_str=str1.lower()

# %%
print(new_str)
# Out:
# jai ganesh

# %% [markdown]
# upper( )

# %%
str1="jai ganesh"

# %%
new_str4=str1.upper()

# %%
print(new_str4)
# Out:
# JAI GANESH
