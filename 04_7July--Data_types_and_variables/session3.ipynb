# %% [markdown]
# # Python

# %% [markdown]
# ## Python

# %% [markdown]
# ### Python

# %% [markdown]
# #### Python

# %% [markdown]
# ##### Python

# %% [markdown]
# # Python Basic data types

# %% [markdown]
# ### 1.Interger (int)

# %% [markdown]
# #### 1.decimal representation

# %%
decimal_num=10

# %%
print(decimal_num)
# Out:
# 10

# %%
print(type(decimal_num))
# Out:
# <class 'int'>

# %% [markdown]
# #### 2.binary representation

# %%
binary_num=0b1010

# %%
print(binary_num)
# Out:
# 10

# %%
print(type(binary_num))
# Out:
# <class 'int'>

# %% [markdown]
# #### 3.octal representation

# %%
octal_num=0o12

# %%
print(octal_num)
# Out:
# 10

# %%
print(type(octal_num))
# Out:
# <class 'int'>

# %% [markdown]
# #### 4.hexadecimal representation

# %%
hexadecimal_num=0xA

# %%
print(hexadecimal_num)
# Out:
# 10

# %%
print(type(hexadecimal_num))
# Out:
# <class 'int'>

# %% [markdown]
# ### 2.float (float)

# %% [markdown]
# #### 1.decimal notation

# %%
pi=3.14

# %%
print(pi)
# Out:
# 3.14

# %%
print(type(pi))
# Out:
# <class 'float'>

# %% [markdown]
# #### 2. exponential notation

# %%
var1=6.02e23

# %%
print(var1)
# Out:
# 6.02e+23

# %%
print(type(var1))
# Out:
# <class 'float'>

# %% [markdown]
# ## 3. complex (complex)

# %%
var2=5+3j

# %%
print(var2)
# Out:
# (5+3j)

# %%
print(type(var2))
# Out:
# <class 'complex'>

# %%
print(var2.real)
# Out:
# 5.0

# %%
print(var2.imag)
# Out:
# 3.0

# %% [markdown]
# ## 4. boolean (bool)

# %%
marks=78

# %%
has_passed=marks>=35

# %%
print(has_passed)
# Out:
# True

# %%
print(type(has_passed))
# Out:
# <class 'bool'>

# %%
marks=27

# %%
has_passed=marks>=35

# %%
print(has_passed)
# Out:
# False

# %%
print(type(has_passed))
# Out:
# <class 'bool'>

# %% [markdown]
# ## 5.String (str)

# %%
city='Pune'

# %%
course= "Artificial Intelligence"

# %%
course_desc= """ 
This is the very comprehensive course about
Artificial intelligence
"""

# %%
print(city)
# Out:
# Pune

# %%
print(course)
# Out:
# Artificial Intelligence

# %%
print(course_desc)
# Out:
#
# This is the very comprehensive course about
# Artificial intelligence

# %%
print(type(city))
# Out:
# <class 'str'>

# %%
print(type(course))
# Out:
# <class 'str'>

# %%
print(type(course_desc))
# Out:
# <class 'str'>

# %% [markdown]
# ## Variable assignment( dynamic typing)

# %%
age=25

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
age="twenty-five"

# %%
print(type(age))
# Out:
# <class 'str'>

# %%
age=25+0j

# %%
print(type(age))
# Out:
# <class 'complex'>

# %%
age=25.0

# %%
print(type(age))
# Out:
# <class 'float'>

# %%
age=True

# %%
print(age)
# Out:
# True

# %%
print(type(age))
# Out:
# <class 'bool'>

# %% [markdown]
# ## Muiltiple variables assignment

# %%
length=12
breadth=8
height=5

# %%
length, breadth, height=12,8,5

# %%
print(length,breadth,height)
# Out:
# 12 8 5

# %%
length=breadth=height=12

# %%
print(length,breadth,height)
# Out:
# 12 12 12
