# %% [markdown]
# ## Arithmatic Operators

# %% [markdown]
# #### 1.Addition (+)

# %%
p=12

# %%
q=4

# %%
print(p)
# Out:
# 12

# %%
print(q)
# Out:
# 4

# %%
result= p+q

# %%
print(result)
# Out:
# 16

# %%
result2=12+5

# %%
print(result2)
# Out:
# 17

# %% [markdown]
# #### 2.subtraction (-)

# %%
p=12

# %%
q=4

# %%
result3=p-q

# %%
print(result3)
# Out:
# 8

# %%
result4=5-10

# %%
print(result4)
# Out:
# -5

# %% [markdown]
# #### 3.Multiplication (*)

# %%
p=12

# %%
q=4

# %%
result5=p*q

# %%
print(result5)
# Out:
# 48

# %%
result6=12*5

# %%
print(result6)
# Out:
# 60

# %% [markdown]
# #### 4.Division (/)

# %%
p=12

# %%
q=4

# %%
result7=p/q

# %%
print(result7)
# Out:
# 3.0

# %%
result8=25/5

# %%
print(result8)
# Out:
# 5.0

# %% [markdown]
# #### 5. Floor Division (//)

# %%
p=12

# %%
q=4

# %%
result9=p//q

# %%
print(result9)
# Out:
# 3

# %% [markdown]
# #### 6.Modulus(%)

# %%
p=12

# %%
q=4

# %%
result10=p%q

# %%
print(result10)
# Out:
# 0

# %%
p=13

# %%
q=4

# %%
result11=p%q

# %%
print(result11)
# Out:
# 1

# %% [markdown]
# #### 7. Exponentiation (**)

# %%
base=4

# %%
power=3

# %%
result12=base**power

# %%
print(result12)
# Out:
# 64

# %%
result13=4**3

# %%
print(result13)
# Out:
# 64

# %%
result14=4**4

# %%
print(result14)
# Out:
# 256

# %% [markdown]
# ## Precedence (Order of Operations)

# %% [markdown]
# #### 1.Parentheses () - Highest precedence

# %%
value=(9+3)*2

# %%
print(value)
# Out:
# 24

# %%
value2=(9+1+1+1+1)*2

# %%
print(value2)
# Out:
# 26

# %% [markdown]
# #### 2.Exponentation- **

# %%
value3=4+2**3

# %%
print(value3)
# Out:
# 12

# %% [markdown]
# #### 3.mul,div,floor div,modulus - *,/,//,%

# %%
value4=18-3*4

# %%
print(value4)
# Out:
# 6

# %% [markdown]
# #### 4. add & sub - + , -

# %%
value5=20-5+3

# %%
print(value5)
# Out:
# 18
