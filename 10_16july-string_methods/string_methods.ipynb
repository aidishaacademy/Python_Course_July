# %% [markdown]
# #### capitalize( )

# %%
str1="jai ganesh"

# %%
new_str=str1.capitalize()

# %%
print(new_str)
# Out:
# Jai ganesh

# %%
str2="HELLO WORLD"

# %%
new_str2=str2.capitalize()

# %%
print(new_str2)
# Out:
# Hello world

# %% [markdown]
# #### title( )

# %%
str1="jai ganesh"

# %%
new_str1=str1.title()

# %%
print(new_str1)
# Out:
# Jai Ganesh

# %%
str2="HELLO WORLD"

# %%
new_str2=str2.title()

# %%
print(new_str2)
# Out:
# Hello World

# %% [markdown]
# #### swapcase( )

# %%
str1="jAI gANESH"

# %%
new_str=str1.swapcase()

# %%
print(new_str)
# Out:
# Jai Ganesh

# %% [markdown]
# ## Built in functions

# %% [markdown]
# #### 1.str( )

# %%
a=20
b=20.1
c=20+1j

# %%
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
new_a=str(a)

# %%
print(new_a)
# Out:
# 20

# %%
print(type(new_a))
# Out:
# <class 'str'>

# %%
new_b=str(b)

# %%
print(new_b)
# Out:
# 20.1

# %%
print(type(new_b))
# Out:
# <class 'str'>

# %%
new_c=str(c)

# %%
print(new_c)
# Out:
# (20+1j)

# %%
print(type(new_c))
# Out:
# <class 'str'>

# %% [markdown]
# #### 2. int( )

# %%
d="10"

# %%
print(d)
# Out:
# 10

# %%
print(type(d))
# Out:
# <class 'str'>

# %%
new_d=int(d)

# %%
print(new_d)
# Out:
# 10

# %%
print(type(new_d))
# Out:
# <class 'int'>

# %% [markdown]
# #### 3. float( )

# %%
e="10.1"

# %%
print(e)
# Out:
# 10.1

# %%
print(type(e))
# Out:
# <class 'str'>

# %%
new_e=float(e)

# %%
print(new_e)
# Out:
# 10.1

# %%
print(type(new_e))
# Out:
# <class 'float'>

# %% [markdown]
# #### 4. complex( )

# %%
num="20+1j"

# %%
print(num)
# Out:
# 20+1j

# %%
print(type(num))
# Out:
# <class 'str'>

# %%
new_num=complex(num)

# %%
print(new_num)
# Out:
# (20+1j)

# %%
print(type(new_num))
# Out:
# <class 'complex'>

# %% [markdown]
# #### split( )

# %%
str1="my name is ganesh"

# %%
print(str1.split())
# Out:
# ['my', 'name', 'is', 'ganesh']

# %% [markdown]
# #### join( )

# %%
words=["my","name","is","ganesh"]

# %%
sentence=" ".join(words)

# %%
print(sentence)
# Out:
# my name is ganesh

# %%
sentence1="|".join(words)

# %%
print(sentence1)
# Out:
# my|name|is|ganesh
