# %% [markdown]
# ## Strings

# %% [markdown]
# #### single quotes

# %%
greetings='jai ganesh'

# %%
print(greetings)
# Out:
# jai ganesh

# %%
print(type(greetings))
# Out:
# <class 'str'>

# %% [markdown]
# #### double quotes

# %%
greetings1="jai ganesh"

# %%
print(greetings1)
# Out:
# jai ganesh

# %%
print(type(greetings1))
# Out:
# <class 'str'>

# %% [markdown]
# #### tripple quotes - multiline strings

# %%
greetings2='''jai ganesh'''

# %%
print(greetings2)
# Out:
# jai ganesh

# %%
print(type(greetings2))
# Out:
# <class 'str'>

# %%
greetings3="""jai ganesh"""

# %%
print(greetings3)
# Out:
# jai ganesh

# %%
print(type(greetings3))
# Out:
# <class 'str'>

# %% [markdown]
# ## Multiline string

# %%
greetings4= '''Hello, good morning
welcome to AI Course'''

#greetings4= """Hello, good morning
#welcome to AI Course"""

# %%
print(greetings4)
# Out:
# Hello, good morning
# welcome to AI Course

# %%
print(type(greetings4))
# Out:
# <class 'str'>

# %%
greetings5= 'Hello, good morning\
welcome to AI Course'

# %%
print(greetings5)
# Out:
# Hello, good morningwelcome to AI Course

# %%
str1= 'let\'s play cricket'

# %%
print(str1)
# Out:
# let's play cricket

# %%
str2="let's play cricket"

# %%
print(str2)
# Out:
# let's play cricket

# %% [markdown]
# ## Indexing

# %%
str1="jai ganesh"

# %%
print(str1)
# Out:
# jai ganesh

# %% [markdown]
# #### Positive indexing

# %%
print(str1[4])
# Out:
# g

# %%
print(str1[-6])
# Out:
# g

# %%
print(str1[0])
# Out:
# j

# %%
print(str1[1])
# Out:
# a

# %%
print(str1[2])
# Out:
# i

# %%
print(str1[3])

# %%
print(str1[4])
# Out:
# g

# %%
print(str1[5])
# Out:
# a

# %%
print(str1[6])
# Out:
# n

# %%
print(str1[7])
# Out:
# e

# %%
print(str1[8])
# Out:
# s

# %%
print(str1[9])
# Out:
# h

# %%
print(str1[10])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 print(str1[10])
#
# IndexError: string index out of range

# %% [markdown]
# #### Negative indexing

# %%
str1="jai ganesh"

# %%
print(str1[-10])
print(str1[-9])
print(str1[-8])
print(str1[-7])
print(str1[-6])
print(str1[-5])
print(str1[-4])
print(str1[-3])
print(str1[-2])
print(str1[-1])
# Out:
# j
# a
# i
#
# g
# a
# n
# e
# s
# h

# %%
print(str1[-11])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 print(str1[-11])
#
# IndexError: string index out of range
